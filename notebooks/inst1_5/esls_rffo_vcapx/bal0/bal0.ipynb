# %%
import os, re
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
geral = pd.DataFrame()
esls = pd.DataFrame()
rffo = pd.DataFrame()
result = pd.DataFrame()

# %%
epsilon = 0.000001

# %%
path='esls/cap000_capw000_caprX/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    esls = esls.append(df[a])

# %%
path='rffo/cap000_capw000_caprX/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    rffo = rffo.append(df[a])

# %%
path='esls/cap150_capw000_caprX/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    esls = esls.append(df[a])

# %%
path='rffo/cap150_capw000_caprX/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    rffo = rffo.append(df[a])

# %%
path='esls/cap175_capw000_caprX/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    esls = esls.append(df[a])

# %%
path='rffo/cap175_capw000_caprX/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    rffo = rffo.append(df[a])

# %%
path='esls/cap200_capw000_caprX/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    esls = esls.append(df[a])

# %%
path='rffo/cap200_capw000_caprX/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    rffo = rffo.append(df[a])

# %%
path='esls/cap000_capwX_capr000/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    esls = esls.append(df[a])

# %%
path='rffo/cap000_capwX_capr000/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    rffo = rffo.append(df[a])

# %%
path='esls/cap150_capwX_capr000/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    esls = esls.append(df[a])

# %%
path='rffo/cap150_capwX_capr000/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    rffo = rffo.append(df[a])

# %%
path='esls/cap175_capwX_capr000/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    esls = esls.append(df[a])

# %%
path='rffo/cap175_capwX_capr000/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    rffo = rffo.append(df[a])

# %%
path='esls/cap200_capwX_capr000/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    esls = esls.append(df[a])

# %%
path='rffo/cap200_capwX_capr000/*.csv'
df = []
files = glob.glob(path)
for a in files:
    try:
        df.append(pd.read_csv(a,header=None,sep=';'))
    except pd.errors.EmptyDataError:
        print('arquivo vazio!',a)
            
for a in range(len(df)):
    rffo = rffo.append(df[a])

# %%
esls.columns = [
    'instance',
    'form',
    'cap',
    'capw',
    'capr',
    'T',
    'W',
    'R',
    'bestbound',
    'bestsol',
    'gap',
    'time',
    'nodes',
    'opt'
]

# %%
rffo.columns = [
    'instance',
    'form',
    'R',
    'T',
    'W',
    'cap',
    'capw',
    'capr',
    'bal',
    'fixsizerf',
    'freeintervalrf',
    'maxtimerf',
    'bestsolrf',
    'timerf',
    'fixsizefo',
    'freeintervalfo',
    'minroundsfo',
    'maxtimefo',
    'incfixfo',
    'inchorfo',
    'bestsolfo',
    'timefo',
    'rounds',
    ]

# %%
esls['opt'] = [ 1 if s <= epsilon else 0 for s in esls['gap']]

# %%
geral = pd.merge(esls,rffo,how='left',on=['instance','cap','capw','capr','T','W','R'])

# %%
def gap_rffo(row):
    return (row['bestsolfo'] - row['bestbound'])/(row['bestsolfo'])*100

geral['gap_rffo'] = geral.apply(gap_rffo, axis=1)

# %%
def improve_fo_rf(row):
    return (row['bestsolrf'] - row['bestsolfo'])/(row['bestsolrf'])*100

geral['impr_fo_rf'] = geral.apply(improve_fo_rf, axis=1)

# %%
def improve_rffo_esls(row):
    return (row['bestsol'] - row['bestsolfo'])/(row['bestsol'])*100

geral['impr_rffo_esls'] = geral.apply(improve_rffo_esls, axis=1)

# %%
geral['dif'] = geral['bestsol'] - geral['bestsolfo']

# %%
geral['#inst<='] = [ 1 if s >= -epsilon else 0 for s in geral['dif']]

geral['#inst<='].sum()
# Out:
# 2272

# %%
geral['#inst<'] = [ 1 if s >= epsilon else 0 for s in geral['dif']]

geral['#inst<'].sum()
# Out:
# 1374

# %%
geral = geral.append({
    'bestsol':geral['bestsol'].mean(),
    'gap':geral['gap'].mean(),
    'opt':geral['opt'].sum(),
    'bestsolrf':geral['bestsolrf'].mean(),
    'bestsolfo':geral['bestsolfo'].mean(),
    'rounds':geral['rounds'].mean(),
    'gap_rffo':geral['gap_rffo'].mean(),
    'impr_fo_rf':geral['impr_fo_rf'].mean(),
    'impr_rffo_esls':geral['impr_rffo_esls'].mean(),
    '#inst<=':geral['#inst<='].sum(),
    '#inst<':geral['#inst<'].sum(),
}, ignore_index= True)

# %%
geral[[
    'cap',
    'capw',
    'capr',
    'bestsol',
    'gap',
    'opt',
    'bestsolrf',
    'bestsolfo',
    'gap_rffo',
    'impr_fo_rf',
    'impr_rffo_esls',
    '#inst<=',
    '#inst<',
    'rounds'
]]
# Out:
#       cap  capw  capr       bestsol        gap    opt     bestsolrf  \
# 0     0.0   0.0  1.75  1.655106e+06  42.564440    0.0  1.714870e+06
# 1     0.0   0.0  1.75  1.769289e+06  45.745858    0.0  1.707773e+06
# 2     0.0   0.0  1.75  1.180321e+06  18.803363    0.0  1.637807e+06
# 3     0.0   0.0  1.75  1.793903e+06  45.054121    0.0  1.721697e+06
# 4     0.0   0.0  1.75  1.628737e+06  43.866074    0.0  1.589912e+06
# ...   ...   ...   ...           ...        ...    ...           ...
# 2876  2.0   1.5  0.00  1.125040e+06  14.429895    0.0  1.069570e+06
# 2877  2.0   1.5  0.00  1.264601e+06  10.459167    0.0  1.350136e+06
# 2878  2.0   1.5  0.00  1.825973e+06  38.732616    0.0  1.248198e+06
# 2879  2.0   1.5  0.00  1.282627e+06   9.722435    0.0  1.291477e+06
# 2880  NaN   NaN   NaN  8.346854e+05   6.480321  960.0  8.169259e+05
#
#          bestsolfo  gap_rffo  impr_fo_rf  impr_rffo_esls  #inst<=  #inst<  \
# 0     1.008811e+06  5.768341   41.172750       39.048552      1.0     1.0
# ...

# %%
geral.to_csv('cap3lspd_unbal.csv', encoding='utf-8', index=False) # geral.to_csv('cap3lspd_unbal.csv', index=False)

# %%
result = result.append(geral.iloc[2880])

# %%
cap000_capw150_capr000 = pd.DataFrame()
cap000_capw175_capr000 = pd.DataFrame()
cap000_capw200_capr000 = pd.DataFrame()

cap000_capw150_capr000 = geral[(geral['cap']==0.00) & (geral['capw']==1.50) & (geral['capr']==0.00)]
cap000_capw175_capr000 = geral[(geral['cap']==0.00) & (geral['capw']==1.75) & (geral['capr']==0.00)]
cap000_capw200_capr000 = geral[(geral['cap']==0.00) & (geral['capw']==2.00) & (geral['capr']==0.00)]

cap000_capw150_capr000 = cap000_capw150_capr000.append({
    'cap':cap000_capw150_capr000['cap'].iloc[0],
    'capw':cap000_capw150_capr000['capw'].iloc[0],
    'capr':cap000_capw150_capr000['capr'].iloc[0],
    'bestsol':cap000_capw150_capr000['bestsol'].mean(),
    'gap':cap000_capw150_capr000['gap'].mean(),
    'opt':cap000_capw150_capr000['opt'].sum(),
    'bestsolrf':cap000_capw150_capr000['bestsolrf'].mean(),
    'bestsolfo':cap000_capw150_capr000['bestsolfo'].mean(),
    'rounds':cap000_capw150_capr000['rounds'].mean(),
    'gap_rffo':cap000_capw150_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap000_capw150_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap000_capw150_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap000_capw150_capr000['#inst<='].sum(),
    '#inst<':cap000_capw150_capr000['#inst<'].sum()
}, ignore_index= True)

cap000_capw175_capr000 = cap000_capw175_capr000.append({
    'cap':cap000_capw175_capr000['cap'].iloc[0],
    'capw':cap000_capw175_capr000['capw'].iloc[0],
    'capr':cap000_capw175_capr000['capr'].iloc[0],
    'bestsol':cap000_capw175_capr000['bestsol'].mean(),
    'gap':cap000_capw175_capr000['gap'].mean(),
    'opt':cap000_capw175_capr000['opt'].sum(),
    'bestsolrf':cap000_capw175_capr000['bestsolrf'].mean(),
    'bestsolfo':cap000_capw175_capr000['bestsolfo'].mean(),
    'rounds':cap000_capw175_capr000['rounds'].mean(),
    'gap_rffo':cap000_capw175_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap000_capw175_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap000_capw175_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap000_capw175_capr000['#inst<='].sum(),
    '#inst<':cap000_capw175_capr000['#inst<'].sum()
}, ignore_index= True)

cap000_capw200_capr000 = cap000_capw200_capr000.append({
    'cap':cap000_capw200_capr000['cap'].iloc[0],
    'capw':cap000_capw200_capr000['capw'].iloc[0],
    'capr':cap000_capw200_capr000['capr'].iloc[0],
    'bestsol':cap000_capw200_capr000['bestsol'].mean(),
    'gap':cap000_capw200_capr000['gap'].mean(),
    'opt':cap000_capw200_capr000['opt'].sum(),
    'bestsolrf':cap000_capw200_capr000['bestsolrf'].mean(),
    'bestsolfo':cap000_capw200_capr000['bestsolfo'].mean(),
    'rounds':cap000_capw200_capr000['rounds'].mean(),
    'gap_rffo':cap000_capw200_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap000_capw200_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap000_capw200_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap000_capw200_capr000['#inst<='].sum(),
    '#inst<':cap000_capw200_capr000['#inst<'].sum()
}, ignore_index= True)

result = result.append(cap000_capw150_capr000.iloc[120])
result = result.append(cap000_capw175_capr000.iloc[120])
result = result.append(cap000_capw200_capr000.iloc[120])

# %%
cap150_capw150_capr000 = pd.DataFrame()
cap150_capw175_capr000 = pd.DataFrame()
cap150_capw200_capr000 = pd.DataFrame()

cap150_capw150_capr000 = geral[(geral['cap']==1.50) & (geral['capw']==1.50) & (geral['capr']==0.00)]
cap150_capw175_capr000 = geral[(geral['cap']==1.50) & (geral['capw']==1.75) & (geral['capr']==0.00)]
cap150_capw200_capr000 = geral[(geral['cap']==1.50) & (geral['capw']==2.00) & (geral['capr']==0.00)]

cap150_capw150_capr000 = cap150_capw150_capr000.append({
    'cap':cap150_capw150_capr000['cap'].iloc[0],
    'capw':cap150_capw150_capr000['capw'].iloc[0],
    'capr':cap150_capw150_capr000['capr'].iloc[0],
    'bestsol':cap150_capw150_capr000['bestsol'].mean(),
    'gap':cap150_capw150_capr000['gap'].mean(),
    'opt':cap150_capw150_capr000['opt'].sum(),
    'bestsolrf':cap150_capw150_capr000['bestsolrf'].mean(),
    'bestsolfo':cap150_capw150_capr000['bestsolfo'].mean(),
    'rounds':cap150_capw150_capr000['rounds'].mean(),
    'gap_rffo':cap150_capw150_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap150_capw150_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap150_capw150_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap150_capw150_capr000['#inst<='].sum(),
    '#inst<':cap150_capw150_capr000['#inst<'].sum()
}, ignore_index= True)

cap150_capw175_capr000 = cap150_capw175_capr000.append({
    'cap':cap150_capw175_capr000['cap'].iloc[0],
    'capw':cap150_capw175_capr000['capw'].iloc[0],
    'capr':cap150_capw175_capr000['capr'].iloc[0],
    'bestsol':cap150_capw175_capr000['bestsol'].mean(),
    'gap':cap150_capw175_capr000['gap'].mean(),
    'opt':cap150_capw175_capr000['opt'].sum(),
    'bestsolrf':cap150_capw175_capr000['bestsolrf'].mean(),
    'bestsolfo':cap150_capw175_capr000['bestsolfo'].mean(),
    'rounds':cap150_capw175_capr000['rounds'].mean(),
    'gap_rffo':cap150_capw175_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap150_capw175_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap150_capw175_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap150_capw175_capr000['#inst<='].sum(),
    '#inst<':cap150_capw175_capr000['#inst<'].sum()
}, ignore_index= True)

cap150_capw200_capr000 = cap150_capw200_capr000.append({
    'cap':cap150_capw200_capr000['cap'].iloc[0],
    'capw':cap150_capw200_capr000['capw'].iloc[0],
    'capr':cap150_capw200_capr000['capr'].iloc[0],
    'bestsol':cap150_capw200_capr000['bestsol'].mean(),
    'gap':cap150_capw200_capr000['gap'].mean(),
    'opt':cap150_capw200_capr000['opt'].sum(),
    'bestsolrf':cap150_capw200_capr000['bestsolrf'].mean(),
    'bestsolfo':cap150_capw200_capr000['bestsolfo'].mean(),
    'rounds':cap150_capw200_capr000['rounds'].mean(),
    'gap_rffo':cap150_capw200_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap150_capw200_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap150_capw200_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap150_capw200_capr000['#inst<='].sum(),
    '#inst<':cap150_capw200_capr000['#inst<'].sum()
}, ignore_index= True)

result = result.append(cap150_capw150_capr000.iloc[120])
result = result.append(cap150_capw175_capr000.iloc[120])
result = result.append(cap150_capw200_capr000.iloc[120])

# %%
cap175_capw150_capr000 = pd.DataFrame()
cap175_capw175_capr000 = pd.DataFrame()
cap175_capw200_capr000 = pd.DataFrame()

cap175_capw150_capr000 = geral[(geral['cap']==1.75) & (geral['capw']==1.50) & (geral['capr']==0.00)]
cap175_capw175_capr000 = geral[(geral['cap']==1.75) & (geral['capw']==1.75) & (geral['capr']==0.00)]
cap175_capw200_capr000 = geral[(geral['cap']==1.75) & (geral['capw']==2.00) & (geral['capr']==0.00)]

cap175_capw150_capr000 = cap175_capw150_capr000.append({
    'cap':cap175_capw150_capr000['cap'].iloc[0],
    'capw':cap175_capw150_capr000['capw'].iloc[0],
    'capr':cap175_capw150_capr000['capr'].iloc[0],
    'bestsol':cap175_capw150_capr000['bestsol'].mean(),
    'gap':cap175_capw150_capr000['gap'].mean(),
    'opt':cap175_capw150_capr000['opt'].sum(),
    'bestsolrf':cap175_capw150_capr000['bestsolrf'].mean(),
    'bestsolfo':cap175_capw150_capr000['bestsolfo'].mean(),
    'rounds':cap175_capw150_capr000['rounds'].mean(),
    'gap_rffo':cap175_capw150_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap175_capw150_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap175_capw150_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap175_capw150_capr000['#inst<='].sum(),
    '#inst<':cap175_capw150_capr000['#inst<'].sum()
}, ignore_index= True)

cap175_capw175_capr000 = cap175_capw175_capr000.append({
    'cap':cap175_capw175_capr000['cap'].iloc[0],
    'capw':cap175_capw175_capr000['capw'].iloc[0],
    'capr':cap175_capw175_capr000['capr'].iloc[0],
    'bestsol':cap175_capw175_capr000['bestsol'].mean(),
    'gap':cap175_capw175_capr000['gap'].mean(),
    'opt':cap175_capw175_capr000['opt'].sum(),
    'bestsolrf':cap175_capw175_capr000['bestsolrf'].mean(),
    'bestsolfo':cap175_capw175_capr000['bestsolfo'].mean(),
    'rounds':cap175_capw175_capr000['rounds'].mean(),
    'gap_rffo':cap175_capw175_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap175_capw175_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap175_capw175_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap175_capw175_capr000['#inst<='].sum(),
    '#inst<':cap175_capw175_capr000['#inst<'].sum()
}, ignore_index= True)

cap175_capw200_capr000 = cap175_capw200_capr000.append({
    'cap':cap175_capw200_capr000['cap'].iloc[0],
    'capw':cap175_capw200_capr000['capw'].iloc[0],
    'capr':cap175_capw200_capr000['capr'].iloc[0],
    'bestsol':cap175_capw200_capr000['bestsol'].mean(),
    'gap':cap175_capw200_capr000['gap'].mean(),
    'opt':cap175_capw200_capr000['opt'].sum(),
    'bestsolrf':cap175_capw200_capr000['bestsolrf'].mean(),
    'bestsolfo':cap175_capw200_capr000['bestsolfo'].mean(),
    'rounds':cap175_capw200_capr000['rounds'].mean(),
    'gap_rffo':cap175_capw200_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap175_capw200_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap175_capw200_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap175_capw200_capr000['#inst<='].sum(),
    '#inst<':cap175_capw200_capr000['#inst<'].sum()
}, ignore_index= True)

result = result.append(cap175_capw150_capr000.iloc[120])
result = result.append(cap175_capw175_capr000.iloc[120])
result = result.append(cap175_capw200_capr000.iloc[120])

# %%
cap200_capw150_capr000 = pd.DataFrame()
cap200_capw175_capr000 = pd.DataFrame()
cap200_capw200_capr000 = pd.DataFrame()

cap200_capw150_capr000 = geral[(geral['cap']==2.00) & (geral['capw']==1.50) & (geral['capr']==0.00)]
cap200_capw175_capr000 = geral[(geral['cap']==2.00) & (geral['capw']==1.75) & (geral['capr']==0.00)]
cap200_capw200_capr000 = geral[(geral['cap']==2.00) & (geral['capw']==2.00) & (geral['capr']==0.00)]

cap200_capw150_capr000 = cap200_capw150_capr000.append({
    'cap':cap200_capw150_capr000['cap'].iloc[0],
    'capw':cap200_capw150_capr000['capw'].iloc[0],
    'capr':cap200_capw150_capr000['capr'].iloc[0],
    'bestsol':cap200_capw150_capr000['bestsol'].mean(),
    'gap':cap200_capw150_capr000['gap'].mean(),
    'opt':cap200_capw150_capr000['opt'].sum(),
    'bestsolrf':cap200_capw150_capr000['bestsolrf'].mean(),
    'bestsolfo':cap200_capw150_capr000['bestsolfo'].mean(),
    'rounds':cap200_capw150_capr000['rounds'].mean(),
    'gap_rffo':cap200_capw150_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap200_capw150_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap200_capw150_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap200_capw150_capr000['#inst<='].sum(),
    '#inst<':cap200_capw150_capr000['#inst<'].sum()
}, ignore_index= True)

cap200_capw175_capr000 = cap200_capw175_capr000.append({
    'cap':cap200_capw175_capr000['cap'].iloc[0],
    'capw':cap200_capw175_capr000['capw'].iloc[0],
    'capr':cap200_capw175_capr000['capr'].iloc[0],
    'bestsol':cap200_capw175_capr000['bestsol'].mean(),
    'gap':cap200_capw175_capr000['gap'].mean(),
    'opt':cap200_capw175_capr000['opt'].sum(),
    'bestsolrf':cap200_capw175_capr000['bestsolrf'].mean(),
    'bestsolfo':cap200_capw175_capr000['bestsolfo'].mean(),
    'rounds':cap200_capw175_capr000['rounds'].mean(),
    'gap_rffo':cap200_capw175_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap200_capw175_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap200_capw175_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap200_capw175_capr000['#inst<='].sum(),
    '#inst<':cap200_capw175_capr000['#inst<'].sum()
}, ignore_index= True)

cap200_capw200_capr000 = cap200_capw200_capr000.append({
    'cap':cap200_capw200_capr000['cap'].iloc[0],
    'capw':cap200_capw200_capr000['capw'].iloc[0],
    'capr':cap200_capw200_capr000['capr'].iloc[0],
    'bestsol':cap200_capw200_capr000['bestsol'].mean(),
    'gap':cap200_capw200_capr000['gap'].mean(),
    'opt':cap200_capw200_capr000['opt'].sum(),
    'bestsolrf':cap200_capw200_capr000['bestsolrf'].mean(),
    'bestsolfo':cap200_capw200_capr000['bestsolfo'].mean(),
    'rounds':cap200_capw200_capr000['rounds'].mean(),
    'gap_rffo':cap200_capw200_capr000['gap_rffo'].mean(),
    'impr_fo_rf':cap200_capw200_capr000['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap200_capw200_capr000['impr_rffo_esls'].mean(),
    '#inst<=':cap200_capw200_capr000['#inst<='].sum(),
    '#inst<':cap200_capw200_capr000['#inst<'].sum()
}, ignore_index= True)

result = result.append(cap200_capw150_capr000.iloc[120])
result = result.append(cap200_capw175_capr000.iloc[120])
result = result.append(cap200_capw200_capr000.iloc[120])

# %%
cap000_capw000_capr150 = pd.DataFrame()
cap000_capw000_capr175 = pd.DataFrame()
cap000_capw00_capr200 = pd.DataFrame()

cap000_capw000_capr150 = geral[(geral['cap']==0.00) & (geral['capw']==0.00) & (geral['capr']==1.50)]
cap000_capw000_capr175 = geral[(geral['cap']==0.00) & (geral['capw']==0.00) & (geral['capr']==1.75)]
cap000_capw000_capr200 = geral[(geral['cap']==0.00) & (geral['capw']==0.00) & (geral['capr']==2.00)]

cap000_capw000_capr150 = cap000_capw000_capr150.append({
    'cap':cap000_capw000_capr150['cap'].iloc[0],
    'capw':cap000_capw000_capr150['capw'].iloc[0],
    'capr':cap000_capw000_capr150['capr'].iloc[0],
    'bestsol':cap000_capw000_capr150['bestsol'].mean(),
    'gap':cap000_capw000_capr150['gap'].mean(),
    'opt':cap000_capw000_capr150['opt'].sum(),
    'bestsolrf':cap000_capw000_capr150['bestsolrf'].mean(),
    'bestsolfo':cap000_capw000_capr150['bestsolfo'].mean(),
    'rounds':cap000_capw000_capr150['rounds'].mean(),
    'gap_rffo':cap000_capw000_capr150['gap_rffo'].mean(),
    'impr_fo_rf':cap000_capw000_capr150['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap000_capw000_capr150['impr_rffo_esls'].mean(),
    '#inst<=':cap000_capw000_capr150['#inst<='].sum(),
    '#inst<':cap000_capw000_capr150['#inst<'].sum()
}, ignore_index= True)

cap000_capw000_capr175 = cap000_capw000_capr175.append({
    'cap':cap000_capw000_capr175['cap'].iloc[0],
    'capw':cap000_capw000_capr175['capw'].iloc[0],
    'capr':cap000_capw000_capr175['capr'].iloc[0],
    'bestsol':cap000_capw000_capr175['bestsol'].mean(),
    'gap':cap000_capw000_capr175['gap'].mean(),
    'opt':cap000_capw000_capr175['opt'].sum(),
    'bestsolrf':cap000_capw000_capr175['bestsolrf'].mean(),
    'bestsolfo':cap000_capw000_capr175['bestsolfo'].mean(),
    'rounds':cap000_capw000_capr175['rounds'].mean(),
    'gap_rffo':cap000_capw000_capr175['gap_rffo'].mean(),
    'impr_fo_rf':cap000_capw000_capr175['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap000_capw000_capr175['impr_rffo_esls'].mean(),
    '#inst<=':cap000_capw000_capr175['#inst<='].sum(),
    '#inst<':cap000_capw000_capr175['#inst<'].sum()
}, ignore_index= True)

cap000_capw000_capr200 = cap000_capw000_capr200.append({
    'cap':cap000_capw000_capr200['cap'].iloc[0],
    'capw':cap000_capw000_capr200['capw'].iloc[0],
    'capr':cap000_capw000_capr200['capr'].iloc[0],
    'bestsol':cap000_capw000_capr200['bestsol'].mean(),
    'gap':cap000_capw000_capr200['gap'].mean(),
    'opt':cap000_capw000_capr200['opt'].sum(),
    'bestsolrf':cap000_capw000_capr200['bestsolrf'].mean(),
    'bestsolfo':cap000_capw000_capr200['bestsolfo'].mean(),
    'rounds':cap000_capw000_capr200['rounds'].mean(),
    'gap_rffo':cap000_capw000_capr200['gap_rffo'].mean(),
    'impr_fo_rf':cap000_capw000_capr200['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap000_capw000_capr200['impr_rffo_esls'].mean(),
    '#inst<=':cap000_capw000_capr200['#inst<='].sum(),
    '#inst<':cap000_capw000_capr200['#inst<'].sum()
}, ignore_index= True)

result = result.append(cap000_capw000_capr150.iloc[120])
result = result.append(cap000_capw000_capr175.iloc[120])
result = result.append(cap000_capw000_capr200.iloc[120])

# %%
cap150_capw000_capr150 = pd.DataFrame()
cap150_capw000_capr175 = pd.DataFrame()
cap150_capw00_capr200 = pd.DataFrame()

cap150_capw000_capr150 = geral[(geral['cap']==1.50) & (geral['capw']==0.00) & (geral['capr']==1.50)]
cap150_capw000_capr175 = geral[(geral['cap']==1.50) & (geral['capw']==0.00) & (geral['capr']==1.75)]
cap150_capw000_capr200 = geral[(geral['cap']==1.50) & (geral['capw']==0.00) & (geral['capr']==2.00)]

cap150_capw000_capr150 = cap150_capw000_capr150.append({
    'cap':cap150_capw000_capr150['cap'].iloc[0],
    'capw':cap150_capw000_capr150['capw'].iloc[0],
    'capr':cap150_capw000_capr150['capr'].iloc[0],
    'bestsol':cap150_capw000_capr150['bestsol'].mean(),
    'gap':cap150_capw000_capr150['gap'].mean(),
    'opt':cap150_capw000_capr150['opt'].sum(),
    'bestsolrf':cap150_capw000_capr150['bestsolrf'].mean(),
    'bestsolfo':cap150_capw000_capr150['bestsolfo'].mean(),
    'rounds':cap150_capw000_capr150['rounds'].mean(),
    'gap_rffo':cap150_capw000_capr150['gap_rffo'].mean(),
    'impr_fo_rf':cap150_capw000_capr150['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap150_capw000_capr150['impr_rffo_esls'].mean(),
    '#inst<=':cap150_capw000_capr150['#inst<='].sum(),
    '#inst<':cap150_capw000_capr150['#inst<'].sum()
}, ignore_index= True)

cap150_capw000_capr175 = cap150_capw000_capr175.append({
    'cap':cap150_capw000_capr175['cap'].iloc[0],
    'capw':cap150_capw000_capr175['capw'].iloc[0],
    'capr':cap150_capw000_capr175['capr'].iloc[0],
    'bestsol':cap150_capw000_capr175['bestsol'].mean(),
    'gap':cap150_capw000_capr175['gap'].mean(),
    'opt':cap150_capw000_capr175['opt'].sum(),
    'bestsolrf':cap150_capw000_capr175['bestsolrf'].mean(),
    'bestsolfo':cap150_capw000_capr175['bestsolfo'].mean(),
    'rounds':cap150_capw000_capr175['rounds'].mean(),
    'gap_rffo':cap150_capw000_capr175['gap_rffo'].mean(),
    'impr_fo_rf':cap150_capw000_capr175['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap150_capw000_capr175['impr_rffo_esls'].mean(),
    '#inst<=':cap150_capw000_capr175['#inst<='].sum(),
    '#inst<':cap150_capw000_capr175['#inst<'].sum()
}, ignore_index= True)

cap150_capw000_capr200 = cap150_capw000_capr200.append({
    'cap':cap150_capw000_capr200['cap'].iloc[0],
    'capw':cap150_capw000_capr200['capw'].iloc[0],
    'capr':cap150_capw000_capr200['capr'].iloc[0],
    'bestsol':cap150_capw000_capr200['bestsol'].mean(),
    'gap':cap150_capw000_capr200['gap'].mean(),
    'opt':cap150_capw000_capr200['opt'].sum(),
    'bestsolrf':cap150_capw000_capr200['bestsolrf'].mean(),
    'bestsolfo':cap150_capw000_capr200['bestsolfo'].mean(),
    'rounds':cap150_capw000_capr200['rounds'].mean(),
    'gap_rffo':cap150_capw000_capr200['gap_rffo'].mean(),
    'impr_fo_rf':cap150_capw000_capr200['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap150_capw000_capr200['impr_rffo_esls'].mean(),
    '#inst<=':cap150_capw000_capr200['#inst<='].sum(),
    '#inst<':cap150_capw000_capr200['#inst<'].sum()
}, ignore_index= True)

result = result.append(cap150_capw000_capr150.iloc[120])
result = result.append(cap150_capw000_capr175.iloc[120])
result = result.append(cap150_capw000_capr200.iloc[120])

# %%
cap175_capw000_capr150 = pd.DataFrame()
cap175_capw000_capr175 = pd.DataFrame()
cap175_capw00_capr200 = pd.DataFrame()

cap175_capw000_capr150 = geral[(geral['cap']==1.75) & (geral['capw']==0.00) & (geral['capr']==1.50)]
cap175_capw000_capr175 = geral[(geral['cap']==1.75) & (geral['capw']==0.00) & (geral['capr']==1.75)]
cap175_capw000_capr200 = geral[(geral['cap']==1.75) & (geral['capw']==0.00) & (geral['capr']==2.00)]

cap175_capw000_capr150 = cap175_capw000_capr150.append({
    'cap':cap175_capw000_capr150['cap'].iloc[0],
    'capw':cap175_capw000_capr150['capw'].iloc[0],
    'capr':cap175_capw000_capr150['capr'].iloc[0],
    'bestsol':cap175_capw000_capr150['bestsol'].mean(),
    'gap':cap175_capw000_capr150['gap'].mean(),
    'opt':cap175_capw000_capr150['opt'].sum(),
    'bestsolrf':cap175_capw000_capr150['bestsolrf'].mean(),
    'bestsolfo':cap175_capw000_capr150['bestsolfo'].mean(),
    'rounds':cap175_capw000_capr150['rounds'].mean(),
    'gap_rffo':cap175_capw000_capr150['gap_rffo'].mean(),
    'impr_fo_rf':cap175_capw000_capr150['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap175_capw000_capr150['impr_rffo_esls'].mean(),
    '#inst<=':cap175_capw000_capr150['#inst<='].sum(),
    '#inst<':cap175_capw000_capr150['#inst<'].sum()
}, ignore_index= True)

cap175_capw000_capr175 = cap175_capw000_capr175.append({
    'cap':cap175_capw000_capr175['cap'].iloc[0],
    'capw':cap175_capw000_capr175['capw'].iloc[0],
    'capr':cap175_capw000_capr175['capr'].iloc[0],
    'bestsol':cap175_capw000_capr175['bestsol'].mean(),
    'gap':cap175_capw000_capr175['gap'].mean(),
    'opt':cap175_capw000_capr175['opt'].sum(),
    'bestsolrf':cap175_capw000_capr175['bestsolrf'].mean(),
    'bestsolfo':cap175_capw000_capr175['bestsolfo'].mean(),
    'rounds':cap175_capw000_capr175['rounds'].mean(),
    'gap_rffo':cap175_capw000_capr175['gap_rffo'].mean(),
    'impr_fo_rf':cap175_capw000_capr175['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap175_capw000_capr175['impr_rffo_esls'].mean(),
    '#inst<=':cap175_capw000_capr175['#inst<='].sum(),
    '#inst<':cap175_capw000_capr175['#inst<'].sum()
}, ignore_index= True)

cap175_capw000_capr200 = cap175_capw000_capr200.append({
    'cap':cap175_capw000_capr200['cap'].iloc[0],
    'capw':cap175_capw000_capr200['capw'].iloc[0],
    'capr':cap175_capw000_capr200['capr'].iloc[0],
    'bestsol':cap175_capw000_capr200['bestsol'].mean(),
    'gap':cap175_capw000_capr200['gap'].mean(),
    'opt':cap175_capw000_capr200['opt'].sum(),
    'bestsolrf':cap175_capw000_capr200['bestsolrf'].mean(),
    'bestsolfo':cap175_capw000_capr200['bestsolfo'].mean(),
    'rounds':cap175_capw000_capr200['rounds'].mean(),
    'gap_rffo':cap175_capw000_capr200['gap_rffo'].mean(),
    'impr_fo_rf':cap175_capw000_capr200['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap175_capw000_capr200['impr_rffo_esls'].mean(),
    '#inst<=':cap175_capw000_capr200['#inst<='].sum(),
    '#inst<':cap175_capw000_capr200['#inst<'].sum()
}, ignore_index= True)

result = result.append(cap175_capw000_capr150.iloc[120])
result = result.append(cap175_capw000_capr175.iloc[120])
result = result.append(cap175_capw000_capr200.iloc[120])

# %%
cap200_capw000_capr150 = pd.DataFrame()
cap200_capw000_capr175 = pd.DataFrame()
cap200_capw00_capr200 = pd.DataFrame()

cap200_capw000_capr150 = geral[(geral['cap']==2.00) & (geral['capw']==0.00) & (geral['capr']==1.50)]
cap200_capw000_capr175 = geral[(geral['cap']==2.00) & (geral['capw']==0.00) & (geral['capr']==1.75)]
cap200_capw000_capr200 = geral[(geral['cap']==2.00) & (geral['capw']==0.00) & (geral['capr']==2.00)]

cap200_capw000_capr150 = cap200_capw000_capr150.append({
    'cap':cap200_capw000_capr150['cap'].iloc[0],
    'capw':cap200_capw000_capr150['capw'].iloc[0],
    'capr':cap200_capw000_capr150['capr'].iloc[0],
    'bestsol':cap200_capw000_capr150['bestsol'].mean(),
    'gap':cap200_capw000_capr150['gap'].mean(),
    'opt':cap200_capw000_capr150['opt'].sum(),
    'bestsolrf':cap200_capw000_capr150['bestsolrf'].mean(),
    'bestsolfo':cap200_capw000_capr150['bestsolfo'].mean(),
    'rounds':cap200_capw000_capr150['rounds'].mean(),
    'gap_rffo':cap200_capw000_capr150['gap_rffo'].mean(),
    'impr_fo_rf':cap200_capw000_capr150['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap200_capw000_capr150['impr_rffo_esls'].mean(),
    '#inst<=':cap200_capw000_capr150['#inst<='].sum(),
    '#inst<':cap200_capw000_capr150['#inst<'].sum()
}, ignore_index= True)

cap200_capw000_capr175 = cap200_capw000_capr175.append({
    'cap':cap200_capw000_capr175['cap'].iloc[0],
    'capw':cap200_capw000_capr175['capw'].iloc[0],
    'capr':cap200_capw000_capr175['capr'].iloc[0],
    'bestsol':cap200_capw000_capr175['bestsol'].mean(),
    'gap':cap200_capw000_capr175['gap'].mean(),
    'opt':cap200_capw000_capr175['opt'].sum(),
    'bestsolrf':cap200_capw000_capr175['bestsolrf'].mean(),
    'bestsolfo':cap200_capw000_capr175['bestsolfo'].mean(),
    'rounds':cap200_capw000_capr175['rounds'].mean(),
    'gap_rffo':cap200_capw000_capr175['gap_rffo'].mean(),
    'impr_fo_rf':cap200_capw000_capr175['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap200_capw000_capr175['impr_rffo_esls'].mean(),
    '#inst<=':cap200_capw000_capr175['#inst<='].sum(),
    '#inst<':cap200_capw000_capr175['#inst<'].sum()
}, ignore_index= True)

cap200_capw000_capr200 = cap200_capw000_capr200.append({
    'cap':cap200_capw000_capr200['cap'].iloc[0],
    'capw':cap200_capw000_capr200['capw'].iloc[0],
    'capr':cap200_capw000_capr200['capr'].iloc[0],
    'bestsol':cap200_capw000_capr200['bestsol'].mean(),
    'gap':cap200_capw000_capr200['gap'].mean(),
    'opt':cap200_capw000_capr200['opt'].sum(),
    'bestsolrf':cap200_capw000_capr200['bestsolrf'].mean(),
    'bestsolfo':cap200_capw000_capr200['bestsolfo'].mean(),
    'rounds':cap200_capw000_capr200['rounds'].mean(),
    'gap_rffo':cap200_capw000_capr200['gap_rffo'].mean(),
    'impr_fo_rf':cap200_capw000_capr200['impr_fo_rf'].mean(),
    'impr_rffo_esls':cap200_capw000_capr200['impr_rffo_esls'].mean(),
    '#inst<=':cap200_capw000_capr200['#inst<='].sum(),
    '#inst<':cap200_capw000_capr200['#inst<'].sum()
}, ignore_index= True)

result = result.append(cap200_capw000_capr150.iloc[120])
result = result.append(cap200_capw000_capr175.iloc[120])
result = result.append(cap200_capw000_capr200.iloc[120])

# %%
result['bestsol'] = result['bestsol'].astype('float64').round(2)
result['gap'] = result['gap'].astype('float64').round(2)
result['opt'] = result['opt'].astype('int').round(0)
result['bestsolrf'] = result['bestsolrf'].astype('float64').round(2)
result['bestsolfo'] = result['bestsolfo'].astype('float64').round(2)
result['rounds'] = result['rounds'].astype('float64').round(2)
result['gap_rffo'] = result['gap_rffo'].astype('float64').round(2)
result['impr_fo_rf'] = result['impr_fo_rf'].astype('float64').round(2)
result['impr_rffo_esls'] = result['impr_rffo_esls'].astype('float64').round(2)
result['#inst<='] = result['#inst<='].astype('int').round(0)
result['#inst<'] = result['#inst<'].astype('int').round(0)

# %%
geral.loc[geral['gap_rffo'] < -0.0001]
# Out:
# Empty DataFrame
# Columns: [instance, form_x, cap, capw, capr, T, W, R, bestbound, bestsol, gap, time, nodes, opt, form_y, bal, fixsizerf, freeintervalrf, maxtimerf, bestsolrf, timerf, fixsizefo, freeintervalfo, minroundsfo, maxtimefo, incfixfo, inchorfo, bestsolfo, timefo, rounds, gap_rffo, impr_fo_rf, impr_rffo_esls, dif, #inst<=, #inst<]
# Index: []
#
# [0 rows x 36 columns]

# %%
result['#inst'] = '120'

# %%
result[[
    'cap',
    'capw',
    'capr',
    '#inst',
    'bestsol',
    'gap',
    'opt',
    'bestsolrf',
    'bestsolfo',
    'gap_rffo',
    'impr_fo_rf',
    'impr_rffo_esls',
    '#inst<=',
    '#inst<',
    'rounds'
]]
# Out:
#        cap  capw  capr #inst     bestsol    gap  opt  bestsolrf  bestsolfo  \
# 2880   NaN   NaN   NaN   120   834685.45   6.48  960  816925.90  743460.02
# 120   0.00  1.50  0.00   120   607501.86   8.33   49  574476.13  483162.53
# 120   0.00  1.75  0.00   120   603603.63   8.18   52  571461.91  482099.47
# 120   0.00  2.00  0.00   120   600162.89   7.88   61  572080.80  480906.80
# 120   1.50  1.50  0.00   120  1069909.11  10.15   11  994423.41  899323.09
# 120   1.50  1.75  0.00   120  1053151.71   9.43   11  985842.44  898659.68
# 120   1.50  2.00  0.00   120  1042370.48   8.96   10  985806.15  898482.92
# 120   1.75  1.50  0.00   120  1016222.15  12.28   17  919156.36  834238.27
# 120   1.75  1.75  0.00   120  1006665.90  11.83   25  915495.80  833203.91
# 120   1.75  2.00  0.00   120   988828.15  10.82   24  912322.79  832210.11
# 120   2.00  1.50  0.00   120   952165.01  12.05   26  854816.90  761682.45
# ...

# %%
result = result.sort_values(by=['cap', 'capw','capr'])

# %%
result["cap"].replace({0.00:'UNC'}, inplace=True)
result["capw"].replace({0.00:'UNC'}, inplace=True)
result["capr"].replace({0.00:'UNC'}, inplace=True)

# %%
result["cap"].replace({np.nan:'ALL'}, inplace=True)
result["capw"].replace({np.nan:'ALL'}, inplace=True)
result["capr"].replace({np.nan:'ALL'}, inplace=True)

# %%
result.loc[2880,'#inst'] = 2880

# %%
result[[
    'cap',
    'capw',
    'capr',
    '#inst',
    'bestsol',
    'gap',
    'opt',
    'bestsolrf',
    'bestsolfo',
    'gap_rffo',
    'impr_fo_rf',
    'impr_rffo_esls',
    '#inst<=',
    '#inst<',
    'rounds'
]]
# Out:
#        cap  capw  capr #inst     bestsol    gap  opt  bestsolrf  bestsolfo  \
# 120    UNC   UNC   1.5   120   484160.51   0.53   90  543917.91  484311.72
# 120    UNC   UNC  1.75   120   541489.87   4.87   76  559477.57  480507.27
# 120    UNC   UNC   2.0   120   544119.62   5.27   72  559475.95  478024.94
# 120    UNC   1.5   UNC   120   607501.86   8.33   49  574476.13  483162.53
# 120    UNC  1.75   UNC   120   603603.63   8.18   52  571461.91  482099.47
# 120    UNC   2.0   UNC   120   600162.89   7.88   61  572080.80  480906.80
# 120    1.5   UNC   1.5   120   902756.38   0.67   34  943362.97  901812.56
# 120    1.5   UNC  1.75   120   932684.83   2.89   26  948801.66  898322.14
# 120    1.5   UNC   2.0   120   937679.52   3.49   23  951317.95  896930.26
# 120    1.5   1.5   UNC   120  1069909.11  10.15   11  994423.41  899323.09
# 120    1.5  1.75   UNC   120  1053151.71   9.43   11  985842.44  898659.68
# ...

# %%
print(result[[
    'cap',
    'capw',
    'capr',
    '#inst',
    'bestsol',
    'gap',
    'opt',
    'bestsolrf',
    'bestsolfo',
    'gap_rffo',
    'impr_fo_rf',
    'impr_rffo_esls',
    '#inst<=',
    '#inst<',
    'rounds'
]].to_latex(index=False))
# Out:
# \begin{tabular}{llllrrrrrrrrrrr}
# \toprule
#   cap &  capw &  capr & \#inst &    bestsol &   gap &  opt &  bestsolrf &  bestsolfo &  gap\_rffo &  impr\_fo\_rf &  impr\_rffo\_esls &  \#inst<= &  \#inst< &  rounds \\
# \midrule
#   UNC &   UNC &   1.5 &   120 &  484160.51 &  0.53 &   90 &  543917.91 &  484311.72 &      0.55 &        5.01 &           -0.02 &      101 &      10 &   15.51 \\
#   UNC &   UNC &  1.75 &   120 &  541489.87 &  4.87 &   76 &  559477.57 &  480507.27 &      0.86 &        6.10 &            4.22 &      110 &      29 &   14.76 \\
#   UNC &   UNC &   2.0 &   120 &  544119.62 &  5.27 &   72 &  559475.95 &  478024.94 &      0.98 &        6.37 &            4.52 &      103 &      29 &   14.40 \\
#   UNC &   1.5 &   UNC &   120 &  607501.86 &  8.33 &   49 &  574476.13 &  483162.53 &      1.19 &        7.00 &            7.48 &      102 &      42 &    9.33 \\
# ...

# %%
ax = cap000_capw150_capr000.plot(
    x='instance', y='gap_rffo', label= 'capw150', figsize=(10, 5), linestyle=':', color="blue"
)
cap000_capw175_capr000.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capw175', linestyle='-', color="red"
)
cap000_capw200_capr000.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capw200', linestyle='-.', color="black"
)
#ax.axes.get_xaxis().set_visible(False)
ax.axes.get_xaxis().set_ticks([])
ax.set_xlabel("instances") 
ax.set_ylabel("gaps_rffo")
plt.legend(framealpha=1, frameon=True);
# estilo = ['-', '--', ':', '-.']

# %%
ax = cap000_capw000_capr150.plot(
    x='instance', y='gap_rffo', label= 'capr150', figsize=(10, 5), linestyle=':', color="blue"
)
cap000_capw000_capr175.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capr175', linestyle='-', color="red"
)
cap000_capw000_capr200.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capr200', linestyle='-.', color="black"
)
#ax.axes.get_xaxis().set_visible(False)
ax.axes.get_xaxis().set_ticks([])
ax.set_xlabel("instances") 
ax.set_ylabel("gaps_rffo")
plt.legend(framealpha=1, frameon=True);

# %%
ax = cap150_capw150_capr000.plot(
    x='instance', y='gap_rffo', label= 'capw150', figsize=(10, 5), linestyle=':', color="blue"
)
cap150_capw175_capr000.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capw175', linestyle='-', color="red"
)
cap150_capw200_capr000.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capw200', linestyle='-.', color="black"
)
#ax.axes.get_xaxis().set_visible(False)
ax.axes.get_xaxis().set_ticks([])
ax.set_xlabel("instances") 
ax.set_ylabel("gaps_rffo")
plt.legend(framealpha=1, frameon=True);

# %%
ax = cap150_capw000_capr150.plot(
    x='instance', y='gap_rffo', label= 'capr150', figsize=(10, 5), linestyle=':', color="blue"
)
cap150_capw000_capr175.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capr175', linestyle='-', color="red"
)
cap150_capw000_capr200.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capr200', linestyle='-.', color="black"
)
#ax.axes.get_xaxis().set_visible(False)
ax.axes.get_xaxis().set_ticks([])
ax.set_xlabel("instances") 
ax.set_ylabel("gaps_rffo")
plt.legend(framealpha=1, frameon=True);

# %%
ax = cap175_capw150_capr000.plot(
    x='instance', y='gap_rffo', label= 'capw150', figsize=(10, 5), linestyle=':', color="blue"
)
cap175_capw175_capr000.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capw175', linestyle='-', color="red"
)
cap175_capw200_capr000.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capw200', linestyle='-.', color="black"
)
#ax.axes.get_xaxis().set_visible(False)
ax.axes.get_xaxis().set_ticks([])
ax.set_xlabel("instances") 
ax.set_ylabel("gaps_rffo")
plt.legend(framealpha=1, frameon=True);

# %%
ax = cap175_capw000_capr150.plot(
    x='instance', y='gap_rffo', label= 'capr150', figsize=(10, 5), linestyle=':', color="blue"
)
cap175_capw000_capr175.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capr175', linestyle='-', color="red"
)
cap175_capw000_capr200.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capr200', linestyle='-.', color="black"
)
#ax.axes.get_xaxis().set_visible(False)
ax.axes.get_xaxis().set_ticks([])
ax.set_xlabel("instances") 
ax.set_ylabel("gaps_rffo")
plt.legend(framealpha=1, frameon=True);

# %%
ax = cap200_capw150_capr000.plot(
    x='instance', y='gap_rffo', label= 'capw150', figsize=(10, 5), linestyle=':', color="blue"
)
cap200_capw175_capr000.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capw175', linestyle='-', color="red"
)
cap200_capw200_capr000.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capw200', linestyle='-.', color="black"
)
#ax.axes.get_xaxis().set_visible(False)
ax.axes.get_xaxis().set_ticks([])
ax.set_xlabel("instances") 
ax.set_ylabel("gaps_rffo")
plt.legend(framealpha=1, frameon=True);

# %%
ax = cap200_capw000_capr150.plot(
    x='instance', y='gap_rffo', label= 'capr150', figsize=(10, 5), linestyle=':', color="blue"
)
cap200_capw000_capr175.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capr175', linestyle='-', color="red"
)
cap200_capw000_capr200.plot(
    ax=ax, x='instance', y='gap_rffo', label= 'capr200', linestyle='-.', color="black"
)
#ax.axes.get_xaxis().set_visible(False)
ax.axes.get_xaxis().set_ticks([])
ax.set_xlabel("instances") 
ax.set_ylabel("gaps_rffo")
plt.legend(framealpha=1, frameon=True);
